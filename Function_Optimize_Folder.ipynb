# %% [markdown]
# ## BOHACHEVSK OPTIMIZE
# ### ![image.png](attachment:image.png)
# ### ![image-2.png](attachment:image-2.png)
# ### Description:Dimensions: 2
#
# The Bohachevsky functions all have the same similar bowl shape. The one shown above is the first function.
#
# Input Domain:
# The functions are usually evaluated on the square xi ∈ [-100, 100], for all i = 1, 2.

# %%
# 可视化

import math
from mpl_toolkits import mplot3d

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def BOHACHEVSK_Function(x1,x2):
    return x1**2+2*(x2**2)-0.3*np.cos(3*math.pi*x1)-0.4*np.cos(4*math.pi*2)+0.7

x1 = np.linspace(-100, 100, 200)
x2 = np.linspace(-100, 100, 200)

X1, X2 = np.meshgrid(x1, x2)

Z = BOHACHEVSK_Function(X1, X2)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X1, X2, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
#优化
from scipy.optimize import minimize

def BOHACHEVSK_Function(x):
    return x[0]**2+2*(x[1]**2)-0.3*np.cos(3*math.pi*x[0])-0.4*np.cos(4*math.pi*x[1])+0.7

x = np.array([-100,-100])

res = minimize(BOHACHEVSK_Function, x, method='nelder-mead',constraints={"fun": h, "type": "eq"}, options={'xtol': 1e-8, 'disp': True})

print(res.x)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.412927
#          Iterations: 83
#          Function evaluations: 167
# [ 6.18612070e-01 -1.51209051e-09]
